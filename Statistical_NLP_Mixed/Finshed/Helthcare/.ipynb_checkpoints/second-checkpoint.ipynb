# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df=pd.read_csv('healthcare_dataset.csv')

# %%
df['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal        18627
# Normal          18517
# Inconclusive    18356
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 27706    sTEVeN GibsON   42    Male         B+           Obesity
# 4208     JOShua hoLmes   59    Male         B+            Cancer
# 25346       jamEs haLL   34    Male        AB+            Cancer
# 50145  tImotHY sTeVENS   59  Female         A-            Cancer
# 20370     BLakE mORrow   37  Female         O+            Asthma
#
#       Date of Admission            Doctor          Hospital  \
# 27706        2022-10-13        Amy Zamora        Cantu-Gray
# 4208         2023-06-28    Kristina Reyes       Stewart PLC
# 25346        2022-11-11  Jessica Shepherd       Collins Inc
# 50145        2023-06-02        Amy Clarke         Clark LLC
# 20370        2022-07-13     Anthony Baker  Cummings-Stanley
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 27706           Medicare    13836.878609          287         Urgent
# 4208               Aetna    19565.792789          421         Urgent
# 25346              Aetna    37323.622435          133       Elective
# 50145              Aetna    17158.358303          467      Emergency
# 20370              Aetna    27701.842435          224       Elective
#
#       Discharge Date   Medication Test Results
# 27706     2022-10-14      Aspirin     Abnormal
# 4208      2023-07-07    Ibuprofen       Normal
# 25346     2022-11-16      Lipitor     Abnormal
# 50145     2023-06-10  Paracetamol       Normal
# 20370     2022-08-06  Paracetamol     Abnormal

# %%
#Data Cleaning

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df['Medical Condition'].value_counts()
df['Medication'].value_counts()
# Out:
# Medication
# Lipitor        11140
# Ibuprofen      11127
# Aspirin        11094
# Paracetamol    11071
# Penicillin     11068
# Name: count, dtype: int64

# %%
# Encodeing  All Input Columns

# %%
# Data Spliting 
x=df.drop(columns=['Test Results'])
y=df['Test Results']

# %%
# Feture Selection
x=x.drop(['Name','Date of Admission','Doctor','Discharge Date','Hospital'],axis=1)

# %%
# Splitting 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Now Encodeing label Encoder Menually 
x_train['Gender']=x_train['Gender'].replace({'Male':0,'Female':1})
x_test['Gender']=x_test['Gender'].replace({'Male':0,'Female':1})

#Label Encoder Apply in sklearn with Blood Type
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x_train['Blood Type']=le.fit_transform(x_train['Blood Type'])
x_test['Blood Type']=le.transform(x_test['Blood Type'])

# label Encoding in Insurance Provider
le=LabelEncoder()
x_train['Insurance Provider']=le.fit_transform(x_train['Insurance Provider'])
x_test['Insurance Provider']=le.transform(x_test['Insurance Provider'])
# Out:
# /tmp/ipykernel_4161/2862606866.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x_train['Gender']=x_train['Gender'].replace({'Male':0,'Female':1})
# /tmp/ipykernel_4161/2862606866.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x_test['Gender']=x_test['Gender'].replace({'Male':0,'Female':1})

# %%
#Label Encoder Apply in sklearn with Blood Type
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x_train['Blood Type']=le.fit_transform(x_train['Blood Type'])
x_test['Blood Type']=le.transform(x_test['Blood Type'])

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define the ordinal structure (from least to most urgent)
urgency_order = [['Elective', 'Urgent', 'Emergency']]

# Initialize the encoder with the defined order
encoder = OrdinalEncoder(categories=urgency_order,handle_unknown='use_encoded_value',unknown_value=-1)

# Fit the encoder ONLY on training data
encoder.fit(x_train[['Admission Type']])  # Double brackets for DataFrame input

# Transform both train and test data
x_train['Encoded_adtype'] = encoder.transform(x_train[['Admission Type']])
x_test['Encoded_adtype'] = encoder.transform(x_test[['Admission Type']])

# Drop the original column
x_train= x_train.drop('Admission Type', axis=1)
x_test= x_test.drop('Admission Type', axis=1)

# %%
# Medication lablel Encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x_train['Medication']=le.fit_transform(x_train['Medication'])
x_test['Medication']=le.transform(x_test['Medication'])

# %% [markdown]
# # Data Scaleing

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# নিউমেরিক কলাম নির্বাচন
numeric_cols = ['Age', 'Billing Amount', 'Room Number']

# স্কেলার ইনিশিয়ালাইজ
scaler = StandardScaler()

# শুধু ট্রেন ডেটায় ফিট করুন
scaler.fit(x_train[numeric_cols])

# ট্রেন এবং টেস্ট ডেটা স্কেল করুন
x_train[numeric_cols] = scaler.transform(x_train[numeric_cols])
x_test[numeric_cols] = scaler.transform(x_test[numeric_cols])

# এখন x_train এবং x_test-এ মূল কলামই স্কেল্ড ভ্যালু ধারণ করছে

# %% [markdown]
# # Traget Column Encodeing

# %%
# উদাহরণ ডেটা
# y = ['নিম্ন', 'মধ্যম', 'উচ্চ', 'মধ্যম', 'নিম্ন']

from sklearn.preprocessing import LabelEncoder
# লেবেল এনকোডিং
le = LabelEncoder()
y_encoded = le.fit_transform(y)

print("ম্যাপিং:", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# ম্যাপিং: {'Abnormal': 0, 'Inconclusive': 1, 'Normal': 2}

# %% [markdown]
# # Model Apply

# %%
from sklearn.linear_model import LogisticRegression

# %%
# মডেল ইনিশিয়ালাইজ
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# প্রেডিকশন
y_pred = model.predict(x_test)

# একুরেসি
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.9}")

# কনফিউশন ম্যাট্রিক্স
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# ক্লাসিফিকেশন রিপোর্ট
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.342612613
#
# Confusion Matrix:
# [[1937  804 1013]
#  [1811  800 1006]
#  [1855  808 1066]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Abnormal       0.35      0.52      0.41      3754
# Inconclusive       0.33      0.22      0.27      3617
#       Normal       0.35      0.29      0.31      3729
#
#     accuracy                           0.34     11100
#    macro avg       0.34      0.34      0.33     11100
# weighted avg       0.34      0.34      0.33     11100

# %%
y_pred
# Out:
# array(['Abnormal', 'Inconclusive', 'Normal', ..., 'Abnormal',
#        'Inconclusive', 'Normal'], dtype=object)
